# %%
#Clean & thoroughly explained version of Lab 1 work. This will (hopefully) be the notebook we submit.

# %% [markdown]
# # 5.1.1

# %%
#packages

import ugradio 
import numpy as np
import matplotlib.pyplot as plt

# %%
#Testing Question Marks
?
#Testing Question Marks
??

# %% [markdown]
# # 5.3

# %% [markdown]
# # 100kHz Data Comprehension (1.5e6 SR)

# %%
#Harvest our data for 400,000 Hz
data400kHz = np.load("freq400khz_data.npz")

#Display our data for 400,000 Hz
data400_kHz = data400kHz['arr_0']
print(data400_kHz)
# Out:
# NpzFile 'freq400khz_data.npz' with keys: arr_0

# %%
#Display our data for 400,000 Hz
data400_kHz = data400kHz['arr_0']
print(data400_kHz)
# Out:
# [[  -2   14    0 ...  127 -128  -76]
#  [ 127  127 -128 ...   79 -128  127]
#  [ 127  -85 -128 ... -128  -83  127]
#  ...
#  [  33  127   90 ...  127  -27 -128]
#  [ 127  127 -128 ...  127 -128   24]
#  [ 127  105 -128 ...  -16 -128  127]]

# %%
#cut out 0th array
