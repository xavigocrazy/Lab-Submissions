# %%
#Clean & thoroughly explained version of Lab 1 work. This will (hopefully) be the notebook we submit.

# %% [markdown]
# # 5.1.1

# %%
#packages

import ugradio 
import numpy as np
import matplotlib.pyplot as plt
import zipfile
import os

# %%
#Testing Question Marks
?
#Testing Question Marks
??

# %% [markdown]
# # 5.3

# %% [markdown]
# # 100kHz-500kHz Data Comprehension (1.5e6 SR)

# %%
data = np.load("data_sr_1.5e6_freq_100.npz")
data10015 = data['arr_0']
plt.figure()
plt.plot(data10015[1])
plt.axis([0,100,-140,140])
plt.title(f"Graph for row: {rows}")
#X axis is groups of sampling rate
#Voltage is y
plt.xlabel("Sampling Index ()")
plt.ylabel("Voltage")
plt.show()

# %%
data = np.load("data_sr_1.5e6_freq_200.npz")
data20015 = data['arr_0']
plt.figure()
plt.plot(data20015[1])
plt.axis([0,100,-140,140])
plt.title(f"Graph for row: {rows}")
#X axis is groups of sampling rate
#Voltage is y
plt.xlabel("Sampling Index ()")
plt.ylabel("Voltage")
plt.show()

# %%
data = np.load("data_sr_1.5e6_freq_300.npz")
data30015 = data['arr_0']
plt.figure()
plt.plot(data30015[1])
plt.axis([0,100,-140,140])
plt.title(f"Graph for row: {rows}")
#X axis is groups of sampling rate
#Voltage is y
plt.xlabel("Sampling Index ()")
plt.ylabel("Voltage")
plt.show()

# %%
data = np.load("data_sr_1.5e6_freq_400.npz")
data40015 = data['arr_0']
plt.figure()
plt.plot(data40015[1])
plt.axis([0,100,-140,140])
plt.title(f"Graph for row: {rows}")
#X axis is groups of sampling rate
#Voltage is y
plt.xlabel("Sampling Index ()")
plt.ylabel("Voltage")
plt.show()

# %%
data = np.load("data_sr_1.5e6_freq_500.npz")
data50015 = data['arr_0']
plt.figure()
plt.plot(data50015[1])
plt.axis([0,100,-140,140])
plt.title(f"Graph for row: {rows}")
#X axis is groups of sampling rate
#Voltage is y
plt.xlabel("Sampling Index ()")
plt.ylabel("Voltage")
plt.show()
